# %% [markdown]
# [Lehrerweiterbildung 2022](https://schulen-jupyter.inf.hszg.de/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fdanielmpla%2Flehrerweiterbildung-2022&urlpath=lab%2Ftree%2Flehrerweiterbildung-2022%2F&branch=main)

# %% [markdown]
# # Anleitung
#
# Auf der Seite https://jupyterhub.github.io/nbgitpuller/link können Links wie oben mit Hilfe eines öffentlichen Git-Repositories erstellt werden (siehe unten). Der hier erstellte Link checkt das Repository aus und aktualisiert den lokalen Ordner bei Bedarf.
#
# <img src="data:image/jpeg;base64,..."></img>

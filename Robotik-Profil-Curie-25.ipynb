# %% [markdown]
# [Robotik-Profil 2025](https://schulen-jupyter.inf.hszg.de/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Ffalkogawantka%2Frobotik-profil-curie&urlpath=lab%2Ftree%2Frobotik-profil-curie%2F&branch=working%2F2026-gr2)
